# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import json
import seaborn as sns
import re
from IPython.core.display import HTML

# %%
orange = pd.read_csv('../data/orange_oct7.csv')
dauphin = pd.read_csv('../data/dauphin_oct7.csv')
gulfport = pd.read_csv('../data/gulfport_oct7.csv')
tybee = pd.read_csv('../data/tybee_oct7.csv')
panama = pd.read_csv('../data/panama_oct7.csv')
miramar = pd.read_csv('../data/miramar_oct7.csv')
palms = pd.read_csv('../data/palms_oct7.csv')

# %% [markdown]
# ## Orange

# %%
orange = orange.drop_duplicates('data.results.listings.listingId')

# %%
orange = orange.rename(columns={'data.results.listings.bedrooms':'bedrooms', 'data.results.listings.propertyType':'type',
       'data.results.listings.sleeps':'sleeps', 'data.results.listings.petsAllowed':'pets_allowed',
       'data.results.listings.averageRating':'rating',
       'data.results.listings.reviewCount':'review_count',
       'data.results.listings.bathrooms.full':'full_bathrooms',
       'data.results.listings.bathrooms.half':'half_bathrooms',
        'data.results.listings.prices.perNight.roundedFormattedAmount':'cost_night',
       'data.results.listings.geoCode.latitude':'latitude',
       'data.results.listings.geoCode.longitude':'longitude', 'data.results.listings.images[0].c6_uri':'image_url'})

# %%
orange = orange.drop(columns = {'data.results.listings.virtualTourBadge',
       'data.results.listings.listingId',
       'data.results.listings.detailPageUrl',
       'data.results.listings.instantBookable',
       'data.results.listings.listingNumber',
       'data.results.listings.propertyId',
        'data.results.listings.__typename',
        'data.results.listings.minStayRange.minStayHigh',
       'data.results.listings.minStayRange.minStayLow',
       'data.results.listings.minStayRange.__typename',
       'data.results.listings.propertyMetadata.headline',
       'data.results.listings.propertyMetadata.__typename',
       'data.results.listings.unitMetadata.unitName',
       'data.results.listings.unitMetadata.__typename',
        'data.results.listings.bathrooms.toiletOnly',
       'data.results.listings.bathrooms.__typename',
       'data.results.listings.spaces.__typename',
       'data.results.listings.spaces.spacesSummary.bedCountDisplay',
       'data.results.listings.spaces.spacesSummary.__typename',
       'data.results.listings.spaces.spacesSummary.area.areaValue',
       'data.results.listings.spaces.spacesSummary.area.__typename',
       'data.results.listings.geoDistance.text',
       'data.results.listings.geoDistance.relationType',
       'data.results.listings.geoDistance.__typename',
       'data.results.listings.priceSummary.priceAccurate',
       'data.results.listings.priceSummary.priceTypeId',
       'data.results.listings.priceSummary.edapEventJson',
       'data.results.listings.priceSummary.formattedAmount',
       'data.results.listings.priceSummary.roundedFormattedAmount',
       'data.results.listings.priceSummary.pricePeriodDescription',
       'data.results.listings.priceSummary.__typename',
       'data.results.listings.priceSummarySecondary.priceTypeId',
       'data.results.listings.priceSummarySecondary.edapEventJson',
       'data.results.listings.priceSummarySecondary.formattedAmount',
       'data.results.listings.priceSummarySecondary.roundedFormattedAmount',
       'data.results.listings.priceSummarySecondary.pricePeriodDescription',
       'data.results.listings.priceSummarySecondary.__typename',
       'data.results.listings.priceLabel.priceTypeId',
       'data.results.listings.priceLabel.pricePeriodDescription',
       'data.results.listings.priceLabel.__typename',
       'data.results.listings.prices.label',
       'data.results.listings.prices.mainPrice',
       'data.results.listings.prices.__typename',
       'data.results.listings.prices.perNight.amount',
       'data.results.listings.prices.perNight.formattedAmount',
         'data.results.listings.prices.perNight.pricePeriodDescription',
       'data.results.listings.prices.perNight.__typename',
       'data.results.listings.prices.total.amount',
       'data.results.listings.prices.total.formattedAmount',
       'data.results.listings.prices.total.roundedFormattedAmount',
       'data.results.listings.prices.total.pricePeriodDescription',
       'data.results.listings.prices.total.__typename',
        'data.results.listings.geoCode.__typename',
       'data.results.listings.amenitiesBadges[0].id',
       'data.results.listings.amenitiesBadges[0].name',
       'data.results.listings.amenitiesBadges[0].helpText',
       'data.results.listings.amenitiesBadges[0].__typename',
       'data.results.listings.rankedBadges[0].id',
       'data.results.listings.rankedBadges[0].name',
       'data.results.listings.rankedBadges[0].helpText',
       'data.results.listings.rankedBadges[0].__typename',
       'data.results.listings.superlativesBadges[0].id',
       'data.results.listings.superlativesBadges[0].name',
       'data.results.listings.superlativesBadges[0].helpText',
       'data.results.listings.superlativesBadges[0].__typename',
       'data.results.listings.virtualTourBadge.id',
       'data.results.listings.virtualTourBadge.name',
       'data.results.listings.virtualTourBadge.helpText',
       'data.results.listings.virtualTourBadge.__typename',
       'data.results.listings.priceSummary',
       'data.results.listings.priceSummarySecondary',
       'data.results.listings.priceLabel', 'data.results.listings.prices',
        'data.results.id',
       'data.results.propertyRedirectUrl', 'data.results.__typename',
       'data.results.resultCount', 'data.results.page',
       'data.results.pageSize', 'data.results.pageCount',
       'data.results.queryUUID', 'data.results.pinnedListing',
       'data.results.fromRecord', 'data.results.toRecord',
       'data.results.internalTools', 'data.results.typeaheadSuggestion.name',
       'data.results.typeaheadSuggestion.uuid',
       'data.results.typeaheadSuggestion.term',
       'data.results.typeaheadSuggestion.__typename',
       'data.results.geography.name', 'data.results.geography.lbsId',
       'data.results.geography.gaiaId', 'data.results.geography.isGeocoded',
       'data.results.geography.shouldShowMapCentralPin',
       'data.results.geography.__typename',
       'data.results.geography.description',
       'data.results.geography.primaryGeoType',
       'data.results.geography.location.latitude',
       'data.results.geography.location.longitude',
       'data.results.geography.location.__typename',
       'data.results.geography.breadcrumbs[0].name',
       'data.results.geography.breadcrumbs[0].countryCode',
       'data.results.geography.breadcrumbs[0].primaryGeoType',
       'data.results.geography.breadcrumbs[0].__typename',
       'data.results.geography.breadcrumbs[0].location.latitude',
       'data.results.geography.breadcrumbs[0].location.longitude',
       'data.results.geography.breadcrumbs[0].location.__typename',
       'data.results.destination.__typename',
       'data.results.destination.breadcrumbs[0].name',
       'data.results.destination.breadcrumbs[0].url',
       'data.results.destination.breadcrumbs[0].__typename',
       'data.results.destinationMessage.iconText',
       'data.results.destinationMessage.__typename',
       'data.results.destinationMessage.iconTitleText.title',
       'data.results.destinationMessage.iconTitleText.message',
       'data.results.destinationMessage.iconTitleText.icon',
       'data.results.destinationMessage.iconTitleText.messageValueType',
       'data.results.destinationMessage.iconTitleText.link',
       'data.results.destinationMessage.iconTitleText.__typename',
       'data.results.percentBooked.currentPercentBooked',
       'data.results.percentBooked.__typename', 'data.results.parsedParams.q',
       'data.results.parsedParams.sort',
       'data.results.parsedParams.__typename',
       'data.results.parsedParams.coreFilters.adults',
       'data.results.parsedParams.coreFilters.children',
       'data.results.parsedParams.coreFilters.pets',
       'data.results.parsedParams.coreFilters.minBedrooms',
       'data.results.parsedParams.coreFilters.maxBedrooms',
       'data.results.parsedParams.coreFilters.minBathrooms',
       'data.results.parsedParams.coreFilters.maxBathrooms',
       'data.results.parsedParams.coreFilters.minNightlyPrice',
       'data.results.parsedParams.coreFilters.maxNightlyPrice',
       'data.results.parsedParams.coreFilters.minSleeps',
       'data.results.parsedParams.coreFilters.__typename',
       'data.results.parsedParams.dates.arrivalDate',
       'data.results.parsedParams.dates.departureDate',
       'data.results.parsedParams.dates.__typename',
       'data.results.mapViewport.neLat', 'data.results.mapViewport.neLong',
       'data.results.mapViewport.swLat', 'data.results.mapViewport.swLong',
       'data.results.mapViewport.__typename',
       'data.results.globalMessages.alert',
       'data.results.globalMessages.__typename',
       'data.results.globalMessages.banner',
       'data.results.filterGroups[0].__typename',
       'data.results.filterGroups[0].groupInfo.id',
       'data.results.filterGroups[0].groupInfo.name',
       'data.results.filterGroups[0].groupInfo.__typename',
       'data.results.filterGroups[0].filters[0].count',
        'data.results.filterGroups[0].filters[0].checked',
       'data.results.filterGroups[0].filters[0].__typename',
       'data.results.filterGroups[0].filters[0].filter.id',
       'data.results.filterGroups[0].filters[0].filter.name',
       'data.results.filterGroups[0].filters[0].filter.refineByQueryArgument',
       'data.results.filterGroups[0].filters[0].filter.description',
       'data.results.filterGroups[0].filters[0].filter.__typename',
       'data.results.filterGroups[0].filters[0].filter.groupId',
       'errors[0].message', 'errors[0].extensions.errorCode',
       'errors[0].extensions.unit', 'errors[0].extensions.code',
       'errors[0].locations[0].line', 'errors[0].locations[0].column', 'data.results.listings.images[0].__typename',
       'data.results.listings.images[0].mab.banditId',
       'data.results.listings.images[0].mab.payloadId',
       'data.results.listings.images[0].mab.campaignId',
       'data.results.listings.images[0].mab.cached',
       'data.results.listings.images[0].mab.arm',
       'data.results.listings.images[0].mab.__typename', 'data.results.listings.images[0].c9_uri',
       'data.results.listings.images[0].mab', 'data.results.listings.images[0].altText'})

# %%
orange['cost_night'] = orange['cost_night'].str.replace('$', '')
orange['cost_night'] = orange['cost_night'].str.replace(',', '')
# Out:
# C:\Users\bswil\AppData\Local\Temp\ipykernel_18536\1636649862.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orange['cost_night'] = orange['cost_night'].str.replace('$', '')

# %%
orange = orange.drop(171)
orange = orange.drop(174)

# %%
orange['cost_night'] = orange['cost_night'].astype(int)

# %%
orange['half_bathrooms'] = orange['half_bathrooms']/2

# %%
orange['bathrooms'] = orange['full_bathrooms']+orange['half_bathrooms']

# %%
orange = orange.drop(columns={'full_bathrooms', 'half_bathrooms'})

# %%
orange['checkin_month'] = '10'
orange['checkin_day'] = '7'

# %%
orange['location'] = 'Orange Beach'

# %%
orange
# Out:
#      bedrooms   type  sleeps  pets_allowed    rating  review_count  \
# 0           2  Condo       6         False  4.733333            30
# 1           2  House       8         False  4.727272            11
# 2           2  Condo       6         False  4.316667            60
# 3           3  Condo       6         False  4.968421           285
# 4           3  Condo       8         False  4.352272            88
# ..        ...    ...     ...           ...       ...           ...
# 445         4  Condo      12         False  0.000000             0
# 446         3  Condo       8         False  0.000000             0
# 447         2  Condo       6         False  0.000000             0
# 448         2  Condo       6         False  0.000000             0
# 449         4  Condo      16         False  0.000000             0
#
#      cost_night   latitude  longitude  \
# 0           154  30.257898 -87.631808
# 1           298  30.259723 -87.628413
# 2           250  30.265019 -87.605906
# 3           290  30.273182 -87.566208
# 4           239  30.264837 -87.602023
# ..          ...        ...        ...
# 445         808  30.267921 -87.589918
# 446         346  30.272995 -87.566856
# 447         305  30.277786 -87.545286
# 448         284  30.272952 -87.565370
# 449        1110  30.257044 -87.632865
#
#                                              image_url  bathrooms  \
# 0    https://media.vrbo.com/lodging/56000000/555900...        2.0
# 1    https://media.vrbo.com/lodging/78000000/770900...        2.5
# 2    https://media.vrbo.com/lodging/28000000/271300...        2.0
# 3    https://media.vrbo.com/lodging/25000000/248900...        2.0
# 4    https://media.vrbo.com/lodging/74000000/733800...        2.0
# ..                                                 ...        ...
# 445  https://media.vrbo.com/lodging/93000000/928600...        3.0
# 446  https://media.vrbo.com/lodging/93000000/928600...        3.0
# 447  https://media.vrbo.com/lodging/93000000/923500...        2.0
# 448  https://media.vrbo.com/lodging/93000000/928600...        2.0
# 449  https://media.vrbo.com/lodging/91000000/909200...        3.0
#
#     checkin_month checkin_day      location
# 0              10           7  Orange Beach
# 1              10           7  Orange Beach
# 2              10           7  Orange Beach
# 3              10           7  Orange Beach
# 4              10           7  Orange Beach
# ..            ...         ...           ...
# 445            10           7  Orange Beach
# 446            10           7  Orange Beach
# 447            10           7  Orange Beach
# 448            10           7  Orange Beach
# 449            10           7  Orange Beach
#
# [448 rows x 14 columns]

# %% [markdown]
# ## Dauphin

# %%
dauphin = dauphin.drop_duplicates('data.results.listings.listingId')

# %%
dauphin = dauphin.rename(columns={'data.results.listings.bedrooms':'bedrooms', 'data.results.listings.propertyType':'type',
       'data.results.listings.sleeps':'sleeps', 'data.results.listings.petsAllowed':'pets_allowed',
       'data.results.listings.averageRating':'rating',
       'data.results.listings.reviewCount':'review_count',
       'data.results.listings.bathrooms.full':'full_bathrooms',
       'data.results.listings.bathrooms.half':'half_bathrooms',
        'data.results.listings.prices.perNight.roundedFormattedAmount':'cost_night',
       'data.results.listings.geoCode.latitude':'latitude',
       'data.results.listings.geoCode.longitude':'longitude', 'data.results.listings.images[0].c6_uri':'image_url'})

# %%
dauphin = dauphin.drop(columns = {'data.results.listings.virtualTourBadge',
       'data.results.listings.listingId',
       'data.results.listings.detailPageUrl',
       'data.results.listings.instantBookable',
       'data.results.listings.listingNumber',
       'data.results.listings.propertyId',
        'data.results.listings.__typename',
        'data.results.listings.minStayRange.minStayHigh',
       'data.results.listings.minStayRange.minStayLow',
       'data.results.listings.minStayRange.__typename',
       'data.results.listings.propertyMetadata.headline',
       'data.results.listings.propertyMetadata.__typename',
       'data.results.listings.unitMetadata.unitName',
       'data.results.listings.unitMetadata.__typename',
        'data.results.listings.bathrooms.toiletOnly',
       'data.results.listings.bathrooms.__typename',
       'data.results.listings.spaces.__typename',
       'data.results.listings.spaces.spacesSummary.bedCountDisplay',
       'data.results.listings.spaces.spacesSummary.__typename',
       'data.results.listings.spaces.spacesSummary.area.areaValue',
       'data.results.listings.spaces.spacesSummary.area.__typename',
       'data.results.listings.geoDistance.text',
       'data.results.listings.geoDistance.relationType',
       'data.results.listings.geoDistance.__typename',
       'data.results.listings.priceSummary.priceAccurate',
       'data.results.listings.priceSummary.priceTypeId',
       'data.results.listings.priceSummary.edapEventJson',
       'data.results.listings.priceSummary.formattedAmount',
       'data.results.listings.priceSummary.roundedFormattedAmount',
       'data.results.listings.priceSummary.pricePeriodDescription',
       'data.results.listings.priceSummary.__typename',
       'data.results.listings.priceSummarySecondary.priceTypeId',
       'data.results.listings.priceSummarySecondary.edapEventJson',
       'data.results.listings.priceSummarySecondary.formattedAmount',
       'data.results.listings.priceSummarySecondary.roundedFormattedAmount',
       'data.results.listings.priceSummarySecondary.pricePeriodDescription',
       'data.results.listings.priceSummarySecondary.__typename',
       'data.results.listings.priceLabel.priceTypeId',
       'data.results.listings.priceLabel.pricePeriodDescription',
       'data.results.listings.priceLabel.__typename',
       'data.results.listings.prices.label',
       'data.results.listings.prices.mainPrice',
       'data.results.listings.prices.__typename',
       'data.results.listings.prices.perNight.amount',
       'data.results.listings.prices.perNight.formattedAmount',
         'data.results.listings.prices.perNight.pricePeriodDescription',
       'data.results.listings.prices.perNight.__typename',
       'data.results.listings.prices.total.amount',
       'data.results.listings.prices.total.formattedAmount',
       'data.results.listings.prices.total.roundedFormattedAmount',
       'data.results.listings.prices.total.pricePeriodDescription',
       'data.results.listings.prices.total.__typename',
        'data.results.listings.geoCode.__typename',
       'data.results.listings.amenitiesBadges[0].id',
       'data.results.listings.amenitiesBadges[0].name',
       'data.results.listings.amenitiesBadges[0].helpText',
       'data.results.listings.amenitiesBadges[0].__typename',
       'data.results.listings.rankedBadges[0].id',
       'data.results.listings.rankedBadges[0].name',
       'data.results.listings.rankedBadges[0].helpText',
       'data.results.listings.rankedBadges[0].__typename',
       'data.results.listings.superlativesBadges[0].id',
       'data.results.listings.superlativesBadges[0].name',
       'data.results.listings.superlativesBadges[0].helpText',
       'data.results.listings.superlativesBadges[0].__typename',
       'data.results.listings.virtualTourBadge.id',
       'data.results.listings.virtualTourBadge.name',
       'data.results.listings.virtualTourBadge.helpText',
       'data.results.listings.virtualTourBadge.__typename',
       'data.results.listings.priceSummary',
       'data.results.listings.priceSummarySecondary',
       'data.results.listings.priceLabel', 'data.results.listings.prices',
        'data.results.id',
       'data.results.propertyRedirectUrl', 'data.results.__typename',
       'data.results.resultCount', 'data.results.page',
       'data.results.pageSize', 'data.results.pageCount',
       'data.results.queryUUID', 'data.results.pinnedListing',
       'data.results.fromRecord', 'data.results.toRecord',
       'data.results.internalTools', 'data.results.typeaheadSuggestion.name',
       'data.results.typeaheadSuggestion.uuid',
       'data.results.typeaheadSuggestion.term',
       'data.results.typeaheadSuggestion.__typename',
       'data.results.geography.name', 'data.results.geography.lbsId',
       'data.results.geography.gaiaId', 'data.results.geography.isGeocoded',
       'data.results.geography.shouldShowMapCentralPin',
       'data.results.geography.__typename',
       'data.results.geography.description',
       'data.results.geography.primaryGeoType',
       'data.results.geography.location.latitude',
       'data.results.geography.location.longitude',
       'data.results.geography.location.__typename',
       'data.results.geography.breadcrumbs[0].name',
       'data.results.geography.breadcrumbs[0].countryCode',
       'data.results.geography.breadcrumbs[0].primaryGeoType',
       'data.results.geography.breadcrumbs[0].__typename',
       'data.results.geography.breadcrumbs[0].location.latitude',
       'data.results.geography.breadcrumbs[0].location.longitude',
       'data.results.geography.breadcrumbs[0].location.__typename',
       'data.results.destination.__typename',
       'data.results.destination.breadcrumbs[0].name',
       'data.results.destination.breadcrumbs[0].url',
       'data.results.destination.breadcrumbs[0].__typename',
       'data.results.destinationMessage.iconText',
       'data.results.destinationMessage.__typename',
       'data.results.destinationMessage.iconTitleText.title',
       'data.results.destinationMessage.iconTitleText.message',
       'data.results.destinationMessage.iconTitleText.icon',
       'data.results.destinationMessage.iconTitleText.messageValueType',
       'data.results.destinationMessage.iconTitleText.link',
       'data.results.destinationMessage.iconTitleText.__typename',
       'data.results.percentBooked.currentPercentBooked',
       'data.results.percentBooked.__typename', 'data.results.parsedParams.q',
       'data.results.parsedParams.sort',
       'data.results.parsedParams.__typename',
       'data.results.parsedParams.coreFilters.adults',
       'data.results.parsedParams.coreFilters.children',
       'data.results.parsedParams.coreFilters.pets',
       'data.results.parsedParams.coreFilters.minBedrooms',
       'data.results.parsedParams.coreFilters.maxBedrooms',
       'data.results.parsedParams.coreFilters.minBathrooms',
       'data.results.parsedParams.coreFilters.maxBathrooms',
       'data.results.parsedParams.coreFilters.minNightlyPrice',
       'data.results.parsedParams.coreFilters.maxNightlyPrice',
       'data.results.parsedParams.coreFilters.minSleeps',
       'data.results.parsedParams.coreFilters.__typename',
       'data.results.parsedParams.dates.arrivalDate',
       'data.results.parsedParams.dates.departureDate',
       'data.results.parsedParams.dates.__typename',
       'data.results.mapViewport.neLat', 'data.results.mapViewport.neLong',
       'data.results.mapViewport.swLat', 'data.results.mapViewport.swLong',
       'data.results.mapViewport.__typename',
       'data.results.globalMessages.alert',
       'data.results.globalMessages.__typename',
       'data.results.globalMessages.banner',
       'data.results.filterGroups[0].__typename',
       'data.results.filterGroups[0].groupInfo.id',
       'data.results.filterGroups[0].groupInfo.name',
       'data.results.filterGroups[0].groupInfo.__typename',
       'data.results.filterGroups[0].filters[0].count',
        'data.results.filterGroups[0].filters[0].checked',
       'data.results.filterGroups[0].filters[0].__typename',
       'data.results.filterGroups[0].filters[0].filter.id',
       'data.results.filterGroups[0].filters[0].filter.name',
       'data.results.filterGroups[0].filters[0].filter.refineByQueryArgument',
       'data.results.filterGroups[0].filters[0].filter.description',
       'data.results.filterGroups[0].filters[0].filter.__typename',
       'data.results.filterGroups[0].filters[0].filter.groupId',
       'errors[0].message', 'errors[0].extensions.errorCode',
       'errors[0].extensions.unit', 'errors[0].extensions.code',
       'errors[0].locations[0].line', 'errors[0].locations[0].column', 'data.results.listings.images[0].__typename',
       'data.results.listings.images[0].mab.banditId',
       'data.results.listings.images[0].mab.payloadId',
       'data.results.listings.images[0].mab.campaignId',
       'data.results.listings.images[0].mab.cached',
       'data.results.listings.images[0].mab.arm',
       'data.results.listings.images[0].mab.__typename', 'data.results.listings.images[0].c9_uri',
       'data.results.listings.images[0].mab', 'data.results.listings.images[0].altText', 'data.results.listings.prices.total'})

# %%
dauphin['cost_night'] = dauphin['cost_night'].str.replace('$', '')
# Out:
# C:\Users\bswil\AppData\Local\Temp\ipykernel_18536\3667116917.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dauphin['cost_night'] = dauphin['cost_night'].str.replace('$', '')

# %%
dauphin['cost_night'] = dauphin['cost_night'].str.replace(',', '')

# %%
dauphin = dauphin.drop(73)

# %%
dauphin['cost_night'] = dauphin['cost_night'].astype(int)

# %%
dauphin['half_bathrooms'] = dauphin['half_bathrooms']/2

# %%
dauphin['bathrooms'] = dauphin['full_bathrooms']+dauphin['half_bathrooms']

# %%
dauphin = dauphin.drop(columns={'full_bathrooms', 'half_bathrooms'})

# %%
dauphin['checkin_month'] = '10'
dauphin['checkin_day'] = '7'

# %%
dauphin['location'] = 'Dauphin Island'

# %%
dauphin
# Out:
#      bedrooms         type  sleeps  pets_allowed    rating  review_count  \
# 0           3        House       8         False  4.795454            44
# 1           4        House       8         False  5.000000             3
# 2           3        House       8         False  4.777778            18
# 3           2        Condo       6         False  4.875000             8
# 4           2        Condo       6         False  5.000000             1
# ..        ...          ...     ...           ...       ...           ...
# 247         3        House       9         False  4.883333            60
# 248         1  Camp ground       5         False  4.906977            43
# 249         2        House       6         False  5.000000             1
# 250         3        House       6         False  0.000000             0
# 251         4        House      15          True  5.000000             2
#
#      cost_night   latitude  longitude  \
# 0           242  30.255512 -88.137262
# 1           316  30.250673 -88.145703
# 2           200  30.252405 -88.145048
# 3           145  30.260590 -88.112778
# 4           136  30.244760 -88.098330
# ..          ...        ...        ...
# 247         269  30.384223 -88.143268
# 248          86  30.367906 -88.113566
# 249         325  30.361905 -88.114999
# 250         250  30.374629 -88.154852
# 251         686  30.248738 -88.186719
#
#                                              image_url  bathrooms  \
# 0    https://media.vrbo.com/lodging/49000000/488500...        3.0
# 1    https://media.vrbo.com/lodging/79000000/785900...        4.0
# 2    https://media.vrbo.com/lodging/64000000/635000...        2.0
# 3    https://media.vrbo.com/lodging/47000000/469900...        1.0
# 4    https://media.vrbo.com/lodging/84000000/837300...        2.5
# ..                                                 ...        ...
# 247  https://media.vrbo.com/lodging/24000000/235700...        3.0
# 248  https://media.vrbo.com/lodging/71000000/705900...        1.0
# 249  https://media.vrbo.com/lodging/78000000/778700...        3.0
# 250  https://media.vrbo.com/lodging/83000000/829400...        2.0
# 251  https://media.vrbo.com/lodging/77000000/769300...        2.0
#
#     checkin_month checkin_day        location
# 0              10           7  Dauphin Island
# 1              10           7  Dauphin Island
# 2              10           7  Dauphin Island
# 3              10           7  Dauphin Island
# 4              10           7  Dauphin Island
# ..            ...         ...             ...
# 247            10           7  Dauphin Island
# 248            10           7  Dauphin Island
# 249            10           7  Dauphin Island
# 250            10           7  Dauphin Island
# 251            10           7  Dauphin Island
#
# [246 rows x 14 columns]

# %% [markdown]
# ## Panama

# %%
panama = panama.drop_duplicates('data.results.listings.listingId')

# %%
panama = panama.rename(columns={'data.results.listings.bedrooms':'bedrooms', 'data.results.listings.propertyType':'type',
       'data.results.listings.sleeps':'sleeps', 'data.results.listings.petsAllowed':'pets_allowed',
       'data.results.listings.averageRating':'rating',
       'data.results.listings.reviewCount':'review_count',
       'data.results.listings.bathrooms.full':'full_bathrooms',
       'data.results.listings.bathrooms.half':'half_bathrooms',
        'data.results.listings.prices.perNight.roundedFormattedAmount':'cost_night',
       'data.results.listings.geoCode.latitude':'latitude',
       'data.results.listings.geoCode.longitude':'longitude', 'data.results.listings.images[0].c6_uri':'image_url'})

# %%
panama = panama.drop(columns = {'data.results.listings.virtualTourBadge',
       'data.results.listings.listingId',
       'data.results.listings.detailPageUrl',
       'data.results.listings.instantBookable',
       'data.results.listings.listingNumber',
       'data.results.listings.propertyId',
        'data.results.listings.__typename',
        'data.results.listings.minStayRange.minStayHigh',
       'data.results.listings.minStayRange.minStayLow',
       'data.results.listings.minStayRange.__typename',
       'data.results.listings.propertyMetadata.headline',
       'data.results.listings.propertyMetadata.__typename',
       'data.results.listings.unitMetadata.unitName',
       'data.results.listings.unitMetadata.__typename',
        'data.results.listings.bathrooms.toiletOnly',
       'data.results.listings.bathrooms.__typename',
       'data.results.listings.spaces.__typename',
       'data.results.listings.spaces.spacesSummary.bedCountDisplay',
       'data.results.listings.spaces.spacesSummary.__typename',
       'data.results.listings.spaces.spacesSummary.area.areaValue',
       'data.results.listings.spaces.spacesSummary.area.__typename',
       'data.results.listings.geoDistance.text',
       'data.results.listings.geoDistance.relationType',
       'data.results.listings.geoDistance.__typename',
       'data.results.listings.priceSummary.priceAccurate',
       'data.results.listings.priceSummary.priceTypeId',
       'data.results.listings.priceSummary.edapEventJson',
       'data.results.listings.priceSummary.formattedAmount',
       'data.results.listings.priceSummary.roundedFormattedAmount',
       'data.results.listings.priceSummary.pricePeriodDescription',
       'data.results.listings.priceSummary.__typename',
       'data.results.listings.priceSummarySecondary.priceTypeId',
       'data.results.listings.priceSummarySecondary.edapEventJson',
       'data.results.listings.priceSummarySecondary.formattedAmount',
       'data.results.listings.priceSummarySecondary.roundedFormattedAmount',
       'data.results.listings.priceSummarySecondary.pricePeriodDescription',
       'data.results.listings.priceSummarySecondary.__typename',
       'data.results.listings.priceLabel.priceTypeId',
       'data.results.listings.priceLabel.pricePeriodDescription',
       'data.results.listings.priceLabel.__typename',
       'data.results.listings.prices.label',
       'data.results.listings.prices.mainPrice',
       'data.results.listings.prices.__typename',
       'data.results.listings.prices.perNight.amount',
       'data.results.listings.prices.perNight.formattedAmount',
         'data.results.listings.prices.perNight.pricePeriodDescription',
       'data.results.listings.prices.perNight.__typename',
       'data.results.listings.prices.total.amount',
       'data.results.listings.prices.total.formattedAmount',
       'data.results.listings.prices.total.roundedFormattedAmount',
       'data.results.listings.prices.total.pricePeriodDescription',
       'data.results.listings.prices.total.__typename',
        'data.results.listings.geoCode.__typename',
       'data.results.listings.amenitiesBadges[0].id',
       'data.results.listings.amenitiesBadges[0].name',
       'data.results.listings.amenitiesBadges[0].helpText',
       'data.results.listings.amenitiesBadges[0].__typename',
       'data.results.listings.rankedBadges[0].id',
       'data.results.listings.rankedBadges[0].name',
       'data.results.listings.rankedBadges[0].helpText',
       'data.results.listings.rankedBadges[0].__typename',
       'data.results.listings.superlativesBadges[0].id',
       'data.results.listings.superlativesBadges[0].name',
       'data.results.listings.superlativesBadges[0].helpText',
       'data.results.listings.superlativesBadges[0].__typename',
       'data.results.listings.virtualTourBadge.id',
       'data.results.listings.virtualTourBadge.name',
       'data.results.listings.virtualTourBadge.helpText',
       'data.results.listings.virtualTourBadge.__typename',
       'data.results.listings.priceSummary',
       'data.results.listings.priceSummarySecondary',
       'data.results.listings.priceLabel', 'data.results.listings.prices',
        'data.results.id',
       'data.results.propertyRedirectUrl', 'data.results.__typename',
       'data.results.resultCount', 'data.results.page',
       'data.results.pageSize', 'data.results.pageCount',
       'data.results.queryUUID', 'data.results.pinnedListing',
       'data.results.fromRecord', 'data.results.toRecord',
       'data.results.internalTools', 'data.results.typeaheadSuggestion.name',
       'data.results.typeaheadSuggestion.uuid',
       'data.results.typeaheadSuggestion.term',
       'data.results.typeaheadSuggestion.__typename',
       'data.results.geography.name', 'data.results.geography.lbsId',
       'data.results.geography.gaiaId', 'data.results.geography.isGeocoded',
       'data.results.geography.shouldShowMapCentralPin',
       'data.results.geography.__typename',
       'data.results.geography.description',
       'data.results.geography.primaryGeoType',
       'data.results.geography.location.latitude',
       'data.results.geography.location.longitude',
       'data.results.geography.location.__typename',
       'data.results.geography.breadcrumbs[0].name',
       'data.results.geography.breadcrumbs[0].countryCode',
       'data.results.geography.breadcrumbs[0].primaryGeoType',
       'data.results.geography.breadcrumbs[0].__typename',
       'data.results.geography.breadcrumbs[0].location.latitude',
       'data.results.geography.breadcrumbs[0].location.longitude',
       'data.results.geography.breadcrumbs[0].location.__typename',
       'data.results.destination.__typename',
       'data.results.destination.breadcrumbs[0].name',
       'data.results.destination.breadcrumbs[0].url',
       'data.results.destination.breadcrumbs[0].__typename',
       'data.results.destinationMessage.iconText',
       'data.results.destinationMessage.__typename',
       'data.results.destinationMessage.iconTitleText.title',
       'data.results.destinationMessage.iconTitleText.message',
       'data.results.destinationMessage.iconTitleText.icon',
       'data.results.destinationMessage.iconTitleText.messageValueType',
       'data.results.destinationMessage.iconTitleText.link',
       'data.results.destinationMessage.iconTitleText.__typename',
       'data.results.percentBooked.currentPercentBooked',
       'data.results.percentBooked.__typename', 'data.results.parsedParams.q',
       'data.results.parsedParams.sort',
       'data.results.parsedParams.__typename',
       'data.results.parsedParams.coreFilters.adults',
       'data.results.parsedParams.coreFilters.children',
       'data.results.parsedParams.coreFilters.pets',
       'data.results.parsedParams.coreFilters.minBedrooms',
       'data.results.parsedParams.coreFilters.maxBedrooms',
       'data.results.parsedParams.coreFilters.minBathrooms',
       'data.results.parsedParams.coreFilters.maxBathrooms',
       'data.results.parsedParams.coreFilters.minNightlyPrice',
       'data.results.parsedParams.coreFilters.maxNightlyPrice',
       'data.results.parsedParams.coreFilters.minSleeps',
       'data.results.parsedParams.coreFilters.__typename',
       'data.results.parsedParams.dates.arrivalDate',
       'data.results.parsedParams.dates.departureDate',
       'data.results.parsedParams.dates.__typename',
       'data.results.mapViewport.neLat', 'data.results.mapViewport.neLong',
       'data.results.mapViewport.swLat', 'data.results.mapViewport.swLong',
       'data.results.mapViewport.__typename',
       'data.results.globalMessages.alert',
       'data.results.globalMessages.__typename',
       'data.results.globalMessages.banner',
       'data.results.filterGroups[0].__typename',
       'data.results.filterGroups[0].groupInfo.id',
       'data.results.filterGroups[0].groupInfo.name',
       'data.results.filterGroups[0].groupInfo.__typename',
       'data.results.filterGroups[0].filters[0].count',
        'data.results.filterGroups[0].filters[0].checked',
       'data.results.filterGroups[0].filters[0].__typename',
       'data.results.filterGroups[0].filters[0].filter.id',
       'data.results.filterGroups[0].filters[0].filter.name',
       'data.results.filterGroups[0].filters[0].filter.refineByQueryArgument',
       'data.results.filterGroups[0].filters[0].filter.description',
       'data.results.filterGroups[0].filters[0].filter.__typename',
       'data.results.filterGroups[0].filters[0].filter.groupId',
       'errors[0].message', 'errors[0].extensions.errorCode',
       'errors[0].extensions.unit', 'errors[0].extensions.code',
       'errors[0].locations[0].line', 'errors[0].locations[0].column', 'data.results.listings.images[0].__typename',
       'data.results.listings.images[0].mab.banditId',
       'data.results.listings.images[0].mab.payloadId',
       'data.results.listings.images[0].mab.campaignId',
       'data.results.listings.images[0].mab.cached',
       'data.results.listings.images[0].mab.arm',
       'data.results.listings.images[0].mab.__typename', 'data.results.listings.images[0].c9_uri',
       'data.results.listings.images[0].mab', 'data.results.listings.images[0].altText'})

# %%
panama['cost_night'] = panama['cost_night'].str.replace('$', '')
# Out:
# C:\Users\bswil\AppData\Local\Temp\ipykernel_18536\3186132838.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   panama['cost_night'] = panama['cost_night'].str.replace('$', '')

# %%
panama['cost_night'] = panama['cost_night'].str.replace(',', '')

# %%
panama = panama.drop(198)

# %%
panama['cost_night'] = panama['cost_night'].astype(int)

# %%
panama['half_bathrooms'] = panama['half_bathrooms']/2

# %%
panama['bathrooms'] = panama['full_bathrooms']+panama['half_bathrooms']

# %%
panama = panama.drop(columns={'full_bathrooms', 'half_bathrooms'})

# %%
panama['checkin_month'] = '10'
panama['checkin_day'] = '7'

# %%
panama['location'] = 'Panama City Beach'
panama
# Out:
#      bedrooms      type  sleeps  pets_allowed    rating  review_count  \
# 0           2     Condo       8         False  4.600000             5
# 1           1     Condo       6         False  4.909774           133
# 2           3     Condo       8         False  4.291666            24
# 3           3     Condo       8         False  4.800000            35
# 4           3     Condo       8         False  4.625000            16
# ..        ...       ...     ...           ...       ...           ...
# 445         1     Condo       4         False  0.000000             0
# 446         4     Hotel      16          True  0.000000             0
# 447         2     Hotel       8         False  0.000000             0
# 448         1     Condo       4         False  4.142857            14
# 449         2  Townhome       6         False  4.508474            59
#
#      cost_night   latitude  longitude  \
# 0           166  30.177380 -85.804274
# 1           126  30.220471 -85.886436
# 2           240  30.206960 -85.861020
# 3           308  30.176442 -85.805919
# 4           287  30.213661 -85.873580
# ..          ...        ...        ...
# 445         431  30.209025 -85.862710
# 446        1005  30.187962 -85.827066
# 447         350  30.188335 -85.827466
# 448         102  30.175066 -85.804080
# 449         184  30.183625 -85.815588
#
#                                              image_url  bathrooms  \
# 0    https://media.vrbo.com/lodging/76000000/759800...        2.0
# 1    https://media.vrbo.com/lodging/35000000/340900...        2.0
# 2    https://media.vrbo.com/lodging/22000000/217000...        2.0
# 3    https://media.vrbo.com/lodging/47000000/461500...        2.5
# 4    https://media.vrbo.com/lodging/53000000/529700...        2.0
# ..                                                 ...        ...
# 445  https://media.vrbo.com/lodging/92000000/916900...        1.5
# 446  https://media.vrbo.com/lodging/93000000/926000...        2.0
# 447  https://media.vrbo.com/lodging/93000000/928300...        1.0
# 448  https://media.vrbo.com/lodging/34000000/335100...        1.0
# 449  https://media.vrbo.com/lodging/35000000/340900...        2.5
#
#     checkin_month checkin_day           location
# 0              10           7  Panama City Beach
# 1              10           7  Panama City Beach
# 2              10           7  Panama City Beach
# 3              10           7  Panama City Beach
# 4              10           7  Panama City Beach
# ..            ...         ...                ...
# 445            10           7  Panama City Beach
# 446            10           7  Panama City Beach
# 447            10           7  Panama City Beach
# 448            10           7  Panama City Beach
# 449            10           7  Panama City Beach
#
# [445 rows x 14 columns]

# %% [markdown]
# ## Palms

# %%
palms = palms.drop_duplicates('data.results.listings.listingId')

# %%
palms = palms.rename(columns={'data.results.listings.bedrooms':'bedrooms', 'data.results.listings.propertyType':'type',
       'data.results.listings.sleeps':'sleeps', 'data.results.listings.petsAllowed':'pets_allowed',
       'data.results.listings.averageRating':'rating',
       'data.results.listings.reviewCount':'review_count',
       'data.results.listings.bathrooms.full':'full_bathrooms',
       'data.results.listings.bathrooms.half':'half_bathrooms',
        'data.results.listings.prices.perNight.roundedFormattedAmount':'cost_night',
       'data.results.listings.geoCode.latitude':'latitude',
       'data.results.listings.geoCode.longitude':'longitude', 'data.results.listings.images[0].c6_uri':'image_url'})

# %%
palms = palms.drop(columns = {'data.results.listings.virtualTourBadge',
       'data.results.listings.listingId',
       'data.results.listings.detailPageUrl',
       'data.results.listings.instantBookable',
       'data.results.listings.listingNumber',
       'data.results.listings.propertyId',
        'data.results.listings.__typename',
        'data.results.listings.minStayRange.minStayHigh',
       'data.results.listings.minStayRange.minStayLow',
       'data.results.listings.minStayRange.__typename',
       'data.results.listings.propertyMetadata.headline',
       'data.results.listings.propertyMetadata.__typename',
       'data.results.listings.unitMetadata.unitName',
       'data.results.listings.unitMetadata.__typename',
        'data.results.listings.bathrooms.toiletOnly',
       'data.results.listings.bathrooms.__typename',
       'data.results.listings.spaces.__typename',
       'data.results.listings.spaces.spacesSummary.bedCountDisplay',
       'data.results.listings.spaces.spacesSummary.__typename',
       'data.results.listings.spaces.spacesSummary.area.areaValue',
       'data.results.listings.spaces.spacesSummary.area.__typename',
       'data.results.listings.geoDistance.text',
       'data.results.listings.geoDistance.relationType',
       'data.results.listings.geoDistance.__typename',
       'data.results.listings.priceSummary.priceAccurate',
       'data.results.listings.priceSummary.priceTypeId',
       'data.results.listings.priceSummary.edapEventJson',
       'data.results.listings.priceSummary.formattedAmount',
       'data.results.listings.priceSummary.roundedFormattedAmount',
       'data.results.listings.priceSummary.pricePeriodDescription',
       'data.results.listings.priceSummary.__typename',
       'data.results.listings.priceSummarySecondary.priceTypeId',
       'data.results.listings.priceSummarySecondary.edapEventJson',
       'data.results.listings.priceSummarySecondary.formattedAmount',
       'data.results.listings.priceSummarySecondary.roundedFormattedAmount',
       'data.results.listings.priceSummarySecondary.pricePeriodDescription',
       'data.results.listings.priceSummarySecondary.__typename',
       'data.results.listings.priceLabel.priceTypeId',
       'data.results.listings.priceLabel.pricePeriodDescription',
       'data.results.listings.priceLabel.__typename',
       'data.results.listings.prices.label',
       'data.results.listings.prices.mainPrice',
       'data.results.listings.prices.__typename',
       'data.results.listings.prices.perNight.amount',
       'data.results.listings.prices.perNight.formattedAmount',
         'data.results.listings.prices.perNight.pricePeriodDescription',
       'data.results.listings.prices.perNight.__typename',
       'data.results.listings.prices.total.amount',
       'data.results.listings.prices.total.formattedAmount',
       'data.results.listings.prices.total.roundedFormattedAmount',
       'data.results.listings.prices.total.pricePeriodDescription',
       'data.results.listings.prices.total.__typename',
        'data.results.listings.geoCode.__typename',
       'data.results.listings.amenitiesBadges[0].id',
       'data.results.listings.amenitiesBadges[0].name',
       'data.results.listings.amenitiesBadges[0].helpText',
       'data.results.listings.amenitiesBadges[0].__typename',
       'data.results.listings.rankedBadges[0].id',
       'data.results.listings.rankedBadges[0].name',
       'data.results.listings.rankedBadges[0].helpText',
       'data.results.listings.rankedBadges[0].__typename',
       'data.results.listings.superlativesBadges[0].id',
       'data.results.listings.superlativesBadges[0].name',
       'data.results.listings.superlativesBadges[0].helpText',
       'data.results.listings.superlativesBadges[0].__typename',
       'data.results.listings.virtualTourBadge.id',
       'data.results.listings.virtualTourBadge.name',
       'data.results.listings.virtualTourBadge.helpText',
       'data.results.listings.virtualTourBadge.__typename',
       'data.results.listings.priceSummary',
       'data.results.listings.priceSummarySecondary',
       'data.results.listings.priceLabel', 'data.results.listings.prices',
        'data.results.id',
       'data.results.propertyRedirectUrl', 'data.results.__typename',
       'data.results.resultCount', 'data.results.page',
       'data.results.pageSize', 'data.results.pageCount',
       'data.results.queryUUID', 'data.results.pinnedListing',
       'data.results.fromRecord', 'data.results.toRecord',
       'data.results.internalTools', 'data.results.typeaheadSuggestion.name',
       'data.results.typeaheadSuggestion.uuid',
       'data.results.typeaheadSuggestion.term',
       'data.results.typeaheadSuggestion.__typename',
       'data.results.geography.name', 'data.results.geography.lbsId',
       'data.results.geography.gaiaId', 'data.results.geography.isGeocoded',
       'data.results.geography.shouldShowMapCentralPin',
       'data.results.geography.__typename',
       'data.results.geography.description',
       'data.results.geography.primaryGeoType',
       'data.results.geography.location.latitude',
       'data.results.geography.location.longitude',
       'data.results.geography.location.__typename',
       'data.results.geography.breadcrumbs[0].name',
       'data.results.geography.breadcrumbs[0].countryCode',
       'data.results.geography.breadcrumbs[0].primaryGeoType',
       'data.results.geography.breadcrumbs[0].__typename',
       'data.results.geography.breadcrumbs[0].location.latitude',
       'data.results.geography.breadcrumbs[0].location.longitude',
       'data.results.geography.breadcrumbs[0].location.__typename',
       'data.results.destination.__typename',
       'data.results.destination.breadcrumbs[0].name',
       'data.results.destination.breadcrumbs[0].url',
       'data.results.destination.breadcrumbs[0].__typename',
       'data.results.destinationMessage.iconText',
       'data.results.destinationMessage.__typename',
       'data.results.destinationMessage.iconTitleText.title',
       'data.results.destinationMessage.iconTitleText.message',
       'data.results.destinationMessage.iconTitleText.icon',
       'data.results.destinationMessage.iconTitleText.messageValueType',
       'data.results.destinationMessage.iconTitleText.link',
       'data.results.destinationMessage.iconTitleText.__typename',
       'data.results.percentBooked.currentPercentBooked',
       'data.results.percentBooked.__typename', 'data.results.parsedParams.q',
       'data.results.parsedParams.sort',
       'data.results.parsedParams.__typename',
       'data.results.parsedParams.coreFilters.adults',
       'data.results.parsedParams.coreFilters.children',
       'data.results.parsedParams.coreFilters.pets',
       'data.results.parsedParams.coreFilters.minBedrooms',
       'data.results.parsedParams.coreFilters.maxBedrooms',
       'data.results.parsedParams.coreFilters.minBathrooms',
       'data.results.parsedParams.coreFilters.maxBathrooms',
       'data.results.parsedParams.coreFilters.minNightlyPrice',
       'data.results.parsedParams.coreFilters.maxNightlyPrice',
       'data.results.parsedParams.coreFilters.minSleeps',
       'data.results.parsedParams.coreFilters.__typename',
       'data.results.parsedParams.dates.arrivalDate',
       'data.results.parsedParams.dates.departureDate',
       'data.results.parsedParams.dates.__typename',
       'data.results.mapViewport.neLat', 'data.results.mapViewport.neLong',
       'data.results.mapViewport.swLat', 'data.results.mapViewport.swLong',
       'data.results.mapViewport.__typename',
       'data.results.globalMessages.alert',
       'data.results.globalMessages.__typename',
       'data.results.globalMessages.banner',
       'data.results.filterGroups[0].__typename',
       'data.results.filterGroups[0].groupInfo.id',
       'data.results.filterGroups[0].groupInfo.name',
       'data.results.filterGroups[0].groupInfo.__typename',
       'data.results.filterGroups[0].filters[0].count',
        'data.results.filterGroups[0].filters[0].checked',
       'data.results.filterGroups[0].filters[0].__typename',
       'data.results.filterGroups[0].filters[0].filter.id',
       'data.results.filterGroups[0].filters[0].filter.name',
       'data.results.filterGroups[0].filters[0].filter.refineByQueryArgument',
       'data.results.filterGroups[0].filters[0].filter.description',
       'data.results.filterGroups[0].filters[0].filter.__typename',
       'data.results.filterGroups[0].filters[0].filter.groupId',
       'errors[0].message', 'errors[0].extensions.errorCode',
       'errors[0].extensions.unit', 'errors[0].extensions.code',
       'errors[0].locations[0].line', 'errors[0].locations[0].column', 'data.results.listings.images[0].__typename',
       'data.results.listings.images[0].mab.banditId',
       'data.results.listings.images[0].mab.payloadId',
       'data.results.listings.images[0].mab.campaignId',
       'data.results.listings.images[0].mab.cached',
       'data.results.listings.images[0].mab.arm',
       'data.results.listings.images[0].mab.__typename', 'data.results.listings.images[0].c9_uri',
       'data.results.listings.images[0].mab', 'data.results.listings.images[0].altText', 'data.results.listings.webRatingBadges[0].id',
       'data.results.listings.webRatingBadges[0].name',
       'data.results.listings.webRatingBadges[0].helpText',
       'data.results.listings.webRatingBadges[0].__typename'})

# %%
palms['cost_night'] = palms['cost_night'].str.replace('$', '')
# Out:
# C:\Users\bswil\AppData\Local\Temp\ipykernel_18536\3685218847.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   palms['cost_night'] = palms['cost_night'].str.replace('$', '')

# %%
palms['cost_night'] = palms['cost_night'].str.replace(',', '')

# %%
palms = palms.drop(302)

# %%
palms['cost_night'] = palms['cost_night'].astype(int)

# %%
palms['half_bathrooms'] = palms['half_bathrooms']/2

# %%
palms['bathrooms'] = palms['full_bathrooms']+palms['half_bathrooms']

# %%
palms = palms.drop(columns={'full_bathrooms', 'half_bathrooms'})

# %%
palms['checkin_month'] = '10'
palms['checkin_day'] = '7'

# %%
palms['location'] = 'Isle of Palms'
palms
# Out:
#      bedrooms       type  sleeps  pets_allowed    rating  review_count  \
# 0           3      House       8         False  4.571429            14
# 1           3      House       6         False  4.866667            15
# 2           1      Condo       4         False  4.856522           230
# 3           1      Condo       4         False  4.928571            84
# 4           2      Villa       6         False  4.000000            38
# ..        ...        ...     ...           ...       ...           ...
# 444         5      House      10         False  4.285714            14
# 445         8      House      18         False  0.000000             0
# 446         2      Condo       6         False  0.000000             0
# 447         2  Apartment       4         False  0.000000             0
# 448         6      House      12         False  0.000000             0
#
#      cost_night   latitude  longitude  \
# 0           333  32.806016 -79.729756
# 1           319  32.782186 -79.797052
# 2           300  32.785642 -79.786759
# 3           217  32.785991 -79.787327
# 4           181  32.787033 -79.787185
# ..          ...        ...        ...
# 444         957  32.792630 -79.778506
# 445        2430  32.802256 -79.742443
# 446         345  32.804314 -79.754587
# 447         542  32.808901 -79.725123
# 448        1757  32.800457 -79.747607
#
#                                              image_url  bathrooms  \
# 0    https://media.vrbo.com/lodging/67000000/663100...        2.5
# 1    https://media.vrbo.com/lodging/58000000/579200...        2.0
# 2    https://media.vrbo.com/lodging/19000000/190000...        1.0
# 3    https://media.vrbo.com/lodging/65000000/646100...        1.0
# 4    https://media.vrbo.com/lodging/47000000/465600...        2.0
# ..                                                 ...        ...
# 444  https://media.vrbo.com/lodging/92000000/917300...        5.0
# 445  https://media.vrbo.com/lodging/93000000/928500...        7.0
# 446  https://media.vrbo.com/lodging/92000000/916300...        2.0
# 447  https://media.vrbo.com/lodging/92000000/917900...        2.0
# 448  https://media.vrbo.com/lodging/93000000/925900...        6.5
#
#     checkin_month checkin_day       location
# 0              10           7  Isle of Palms
# 1              10           7  Isle of Palms
# 2              10           7  Isle of Palms
# 3              10           7  Isle of Palms
# 4              10           7  Isle of Palms
# ..            ...         ...            ...
# 444            10           7  Isle of Palms
# 445            10           7  Isle of Palms
# 446            10           7  Isle of Palms
# 447            10           7  Isle of Palms
# 448            10           7  Isle of Palms
#
# [447 rows x 14 columns]

# %% [markdown]
# ## Tybee

# %%
tybee = tybee.drop_duplicates('data.results.listings.listingId')

# %%
tybee = tybee.rename(columns={'data.results.listings.bedrooms':'bedrooms', 'data.results.listings.propertyType':'type',
       'data.results.listings.sleeps':'sleeps', 'data.results.listings.petsAllowed':'pets_allowed',
       'data.results.listings.averageRating':'rating',
       'data.results.listings.reviewCount':'review_count',
       'data.results.listings.bathrooms.full':'full_bathrooms',
       'data.results.listings.bathrooms.half':'half_bathrooms',
        'data.results.listings.prices.perNight.roundedFormattedAmount':'cost_night',
       'data.results.listings.geoCode.latitude':'latitude',
       'data.results.listings.geoCode.longitude':'longitude', 'data.results.listings.images[0].c6_uri':'image_url'})

# %%
tybee = tybee.drop(columns = {'data.results.listings.virtualTourBadge',
       'data.results.listings.listingId',
       'data.results.listings.detailPageUrl',
       'data.results.listings.instantBookable',
       'data.results.listings.listingNumber',
       'data.results.listings.propertyId',
        'data.results.listings.__typename',
        'data.results.listings.minStayRange.minStayHigh',
       'data.results.listings.minStayRange.minStayLow',
       'data.results.listings.minStayRange.__typename',
       'data.results.listings.propertyMetadata.headline',
       'data.results.listings.propertyMetadata.__typename',
       'data.results.listings.unitMetadata.unitName',
       'data.results.listings.unitMetadata.__typename',
        'data.results.listings.bathrooms.toiletOnly',
       'data.results.listings.bathrooms.__typename',
       'data.results.listings.spaces.__typename',
       'data.results.listings.spaces.spacesSummary.bedCountDisplay',
       'data.results.listings.spaces.spacesSummary.__typename',
       'data.results.listings.spaces.spacesSummary.area.areaValue',
       'data.results.listings.spaces.spacesSummary.area.__typename',
       'data.results.listings.geoDistance.text',
       'data.results.listings.geoDistance.relationType',
       'data.results.listings.geoDistance.__typename',
       'data.results.listings.priceSummary.priceAccurate',
       'data.results.listings.priceSummary.priceTypeId',
       'data.results.listings.priceSummary.edapEventJson',
       'data.results.listings.priceSummary.formattedAmount',
       'data.results.listings.priceSummary.roundedFormattedAmount',
       'data.results.listings.priceSummary.pricePeriodDescription',
       'data.results.listings.priceSummary.__typename',
       'data.results.listings.priceSummarySecondary.priceTypeId',
       'data.results.listings.priceSummarySecondary.edapEventJson',
       'data.results.listings.priceSummarySecondary.formattedAmount',
       'data.results.listings.priceSummarySecondary.roundedFormattedAmount',
       'data.results.listings.priceSummarySecondary.pricePeriodDescription',
       'data.results.listings.priceSummarySecondary.__typename',
       'data.results.listings.priceLabel.priceTypeId',
       'data.results.listings.priceLabel.pricePeriodDescription',
       'data.results.listings.priceLabel.__typename',
       'data.results.listings.prices.label',
       'data.results.listings.prices.mainPrice',
       'data.results.listings.prices.__typename',
       'data.results.listings.prices.perNight.amount',
       'data.results.listings.prices.perNight.formattedAmount',
         'data.results.listings.prices.perNight.pricePeriodDescription',
       'data.results.listings.prices.perNight.__typename',
       'data.results.listings.prices.total.amount',
       'data.results.listings.prices.total.formattedAmount',
       'data.results.listings.prices.total.roundedFormattedAmount',
       'data.results.listings.prices.total.pricePeriodDescription',
       'data.results.listings.prices.total.__typename',
        'data.results.listings.geoCode.__typename',
       'data.results.listings.amenitiesBadges[0].id',
       'data.results.listings.amenitiesBadges[0].name',
       'data.results.listings.amenitiesBadges[0].helpText',
       'data.results.listings.amenitiesBadges[0].__typename',
       'data.results.listings.rankedBadges[0].id',
       'data.results.listings.rankedBadges[0].name',
       'data.results.listings.rankedBadges[0].helpText',
       'data.results.listings.rankedBadges[0].__typename',
       'data.results.listings.superlativesBadges[0].id',
       'data.results.listings.superlativesBadges[0].name',
       'data.results.listings.superlativesBadges[0].helpText',
       'data.results.listings.superlativesBadges[0].__typename',
       'data.results.listings.virtualTourBadge.id',
       'data.results.listings.virtualTourBadge.name',
       'data.results.listings.virtualTourBadge.helpText',
       'data.results.listings.virtualTourBadge.__typename',
       'data.results.listings.priceSummary',
       'data.results.listings.priceSummarySecondary',
       'data.results.listings.priceLabel', 'data.results.listings.prices',
        'data.results.id',
       'data.results.propertyRedirectUrl', 'data.results.__typename',
       'data.results.resultCount', 'data.results.page',
       'data.results.pageSize', 'data.results.pageCount',
       'data.results.queryUUID', 'data.results.pinnedListing',
       'data.results.fromRecord', 'data.results.toRecord',
       'data.results.internalTools', 'data.results.typeaheadSuggestion.name',
       'data.results.typeaheadSuggestion.uuid',
       'data.results.typeaheadSuggestion.term',
       'data.results.typeaheadSuggestion.__typename',
       'data.results.geography.name', 'data.results.geography.lbsId',
       'data.results.geography.gaiaId', 'data.results.geography.isGeocoded',
       'data.results.geography.shouldShowMapCentralPin',
       'data.results.geography.__typename',
       'data.results.geography.description',
       'data.results.geography.primaryGeoType',
       'data.results.geography.location.latitude',
       'data.results.geography.location.longitude',
       'data.results.geography.location.__typename',
       'data.results.geography.breadcrumbs[0].name',
       'data.results.geography.breadcrumbs[0].countryCode',
       'data.results.geography.breadcrumbs[0].primaryGeoType',
       'data.results.geography.breadcrumbs[0].__typename',
       'data.results.geography.breadcrumbs[0].location.latitude',
       'data.results.geography.breadcrumbs[0].location.longitude',
       'data.results.geography.breadcrumbs[0].location.__typename',
       'data.results.destination.__typename',
       'data.results.destination.breadcrumbs[0].name',
       'data.results.destination.breadcrumbs[0].url',
       'data.results.destination.breadcrumbs[0].__typename',
       'data.results.destinationMessage.iconText',
       'data.results.destinationMessage.__typename',
       'data.results.destinationMessage.iconTitleText.title',
       'data.results.destinationMessage.iconTitleText.message',
       'data.results.destinationMessage.iconTitleText.icon',
       'data.results.destinationMessage.iconTitleText.messageValueType',
       'data.results.destinationMessage.iconTitleText.link',
       'data.results.destinationMessage.iconTitleText.__typename',
       'data.results.percentBooked.currentPercentBooked',
       'data.results.percentBooked.__typename', 'data.results.parsedParams.q',
       'data.results.parsedParams.sort',
       'data.results.parsedParams.__typename',
       'data.results.parsedParams.coreFilters.adults',
       'data.results.parsedParams.coreFilters.children',
       'data.results.parsedParams.coreFilters.pets',
       'data.results.parsedParams.coreFilters.minBedrooms',
       'data.results.parsedParams.coreFilters.maxBedrooms',
       'data.results.parsedParams.coreFilters.minBathrooms',
       'data.results.parsedParams.coreFilters.maxBathrooms',
       'data.results.parsedParams.coreFilters.minNightlyPrice',
       'data.results.parsedParams.coreFilters.maxNightlyPrice',
       'data.results.parsedParams.coreFilters.minSleeps',
       'data.results.parsedParams.coreFilters.__typename',
       'data.results.parsedParams.dates.arrivalDate',
       'data.results.parsedParams.dates.departureDate',
       'data.results.parsedParams.dates.__typename',
       'data.results.mapViewport.neLat', 'data.results.mapViewport.neLong',
       'data.results.mapViewport.swLat', 'data.results.mapViewport.swLong',
       'data.results.mapViewport.__typename',
       'data.results.globalMessages.alert',
       'data.results.globalMessages.__typename',
       'data.results.globalMessages.banner',
       'data.results.filterGroups[0].__typename',
       'data.results.filterGroups[0].groupInfo.id',
       'data.results.filterGroups[0].groupInfo.name',
       'data.results.filterGroups[0].groupInfo.__typename',
       'data.results.filterGroups[0].filters[0].count',
        'data.results.filterGroups[0].filters[0].checked',
       'data.results.filterGroups[0].filters[0].__typename',
       'data.results.filterGroups[0].filters[0].filter.id',
       'data.results.filterGroups[0].filters[0].filter.name',
       'data.results.filterGroups[0].filters[0].filter.refineByQueryArgument',
       'data.results.filterGroups[0].filters[0].filter.description',
       'data.results.filterGroups[0].filters[0].filter.__typename',
       'data.results.filterGroups[0].filters[0].filter.groupId',
       'errors[0].message', 'errors[0].extensions.errorCode',
       'errors[0].extensions.unit', 'errors[0].extensions.code',
       'errors[0].locations[0].line', 'errors[0].locations[0].column', 'data.results.listings.images[0].__typename',
       'data.results.listings.images[0].mab.banditId',
       'data.results.listings.images[0].mab.payloadId',
       'data.results.listings.images[0].mab.campaignId',
       'data.results.listings.images[0].mab.cached',
       'data.results.listings.images[0].mab.arm',
       'data.results.listings.images[0].mab.__typename', 'data.results.listings.images[0].c9_uri',
       'data.results.listings.images[0].mab', 'data.results.listings.images[0].altText', 'data.results.listings.webRatingBadges[0].id',
       'data.results.listings.webRatingBadges[0].name',
       'data.results.listings.webRatingBadges[0].helpText',
       'data.results.listings.webRatingBadges[0].__typename'})

# %%
tybee['cost_night'] = tybee['cost_night'].str.replace('$', '')
# Out:
# C:\Users\bswil\AppData\Local\Temp\ipykernel_18536\3327514090.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tybee['cost_night'] = tybee['cost_night'].str.replace('$', '')

# %%
tybee['cost_night'] = tybee['cost_night'].str.replace(',', '')

# %%
tybee = tybee.drop(51)

# %%
tybee = tybee.drop(58)

# %%
tybee = tybee.drop(81)

# %%
tybee['cost_night'] = tybee['cost_night'].astype(int)

# %%
tybee['half_bathrooms'] = tybee['half_bathrooms']/2

# %%
tybee['bathrooms'] = tybee['full_bathrooms']+tybee['half_bathrooms']

# %%
tybee = tybee.drop(columns={'full_bathrooms', 'half_bathrooms'})

# %%
tybee['checkin_month'] = '10'
tybee['checkin_day'] = '7'

# %%
tybee['location'] = 'Tybee Island'
tybee
# Out:
#      bedrooms      type  sleeps  pets_allowed    rating  review_count  \
# 0           3  Townhome       8         False  4.901409            71
# 1           2     Condo       6         False  4.800000            20
# 2           2     Condo       6          True  4.412698            63
# 3           2     House       5          True  4.939394            33
# 4           2     Condo       4          True  4.000000            68
# ..        ...       ...     ...           ...       ...           ...
# 428         5     House      12         False  0.000000             0
# 429         4     House      15         False  0.000000             0
# 430         5     Condo      10         False  0.000000             0
# 431         6     Condo      12         False  0.000000             0
# 432         6     Condo      18          True  0.000000             0
#
#      cost_night   latitude  longitude  \
# 0           300  32.020743 -80.843894
# 1           291  32.024717 -80.849910
# 2           189  31.990351 -80.848251
# 3           250  32.020148 -80.858273
# 4           328  32.007922 -80.841800
# ..          ...        ...        ...
# 428         878  32.004870 -80.847920
# 429         366  31.998015 -80.847574
# 430        1218  31.993702 -80.849484
# 431        1337  31.993887 -80.849234
# 432        2126  31.998451 -80.848333
#
#                                              image_url  bathrooms  \
# 0    https://media.vrbo.com/lodging/35000000/343400...        3.0
# 1    https://media.vrbo.com/lodging/54000000/531300...        2.0
# 2    https://media.vrbo.com/lodging/48000000/470600...        2.0
# 3    https://media.vrbo.com/lodging/40000000/395400...        2.0
# 4    https://media.vrbo.com/lodging/22000000/217300...        2.0
# ..                                                 ...        ...
# 428  https://media.vrbo.com/lodging/93000000/923600...        3.0
# 429  https://media.vrbo.com/lodging/92000000/917100...        3.0
# 430  https://media.vrbo.com/lodging/93000000/925900...        4.0
# 431  https://media.vrbo.com/lodging/93000000/925900...        5.0
# 432  https://media.vrbo.com/lodging/93000000/929600...        4.0
#
#     checkin_month checkin_day      location
# 0              10           7  Tybee Island
# 1              10           7  Tybee Island
# 2              10           7  Tybee Island
# 3              10           7  Tybee Island
# 4              10           7  Tybee Island
# ..            ...         ...           ...
# 428            10           7  Tybee Island
# 429            10           7  Tybee Island
# 430            10           7  Tybee Island
# 431            10           7  Tybee Island
# 432            10           7  Tybee Island
#
# [419 rows x 14 columns]

# %% [markdown]
# ## Gulfport

# %%
gulfport = gulfport.drop_duplicates('data.results.listings.listingId')

# %%
gulfport = gulfport.rename(columns={'data.results.listings.bedrooms':'bedrooms', 'data.results.listings.propertyType':'type',
       'data.results.listings.sleeps':'sleeps', 'data.results.listings.petsAllowed':'pets_allowed',
       'data.results.listings.averageRating':'rating',
       'data.results.listings.reviewCount':'review_count',
       'data.results.listings.bathrooms.full':'full_bathrooms',
       'data.results.listings.bathrooms.half':'half_bathrooms',
        'data.results.listings.prices.perNight.roundedFormattedAmount':'cost_night',
       'data.results.listings.geoCode.latitude':'latitude',
       'data.results.listings.geoCode.longitude':'longitude', 'data.results.listings.images[0].c6_uri':'image_url'})

# %%
gulfport = gulfport.drop(columns = {'data.results.listings.virtualTourBadge',
       'data.results.listings.listingId',
       'data.results.listings.detailPageUrl',
       'data.results.listings.instantBookable',
       'data.results.listings.listingNumber',
       'data.results.listings.propertyId',
        'data.results.listings.__typename',
        'data.results.listings.minStayRange.minStayHigh',
       'data.results.listings.minStayRange.minStayLow',
       'data.results.listings.minStayRange.__typename',
       'data.results.listings.propertyMetadata.headline',
       'data.results.listings.propertyMetadata.__typename',
       'data.results.listings.unitMetadata.unitName',
       'data.results.listings.unitMetadata.__typename',
        'data.results.listings.bathrooms.toiletOnly',
       'data.results.listings.bathrooms.__typename',
       'data.results.listings.spaces.__typename',
       'data.results.listings.spaces.spacesSummary.bedCountDisplay',
       'data.results.listings.spaces.spacesSummary.__typename',
       'data.results.listings.spaces.spacesSummary.area.areaValue',
       'data.results.listings.spaces.spacesSummary.area.__typename',
       'data.results.listings.geoDistance.text',
       'data.results.listings.geoDistance.relationType',
       'data.results.listings.geoDistance.__typename',
       'data.results.listings.priceSummary.priceAccurate',
       'data.results.listings.priceSummary.priceTypeId',
       'data.results.listings.priceSummary.edapEventJson',
       'data.results.listings.priceSummary.formattedAmount',
       'data.results.listings.priceSummary.roundedFormattedAmount',
       'data.results.listings.priceSummary.pricePeriodDescription',
       'data.results.listings.priceSummary.__typename',
       'data.results.listings.priceSummarySecondary.priceTypeId',
       'data.results.listings.priceSummarySecondary.edapEventJson',
       'data.results.listings.priceSummarySecondary.formattedAmount',
       'data.results.listings.priceSummarySecondary.roundedFormattedAmount',
       'data.results.listings.priceSummarySecondary.pricePeriodDescription',
       'data.results.listings.priceSummarySecondary.__typename',
       'data.results.listings.priceLabel.priceTypeId',
       'data.results.listings.priceLabel.pricePeriodDescription',
       'data.results.listings.priceLabel.__typename',
       'data.results.listings.prices.label',
       'data.results.listings.prices.mainPrice',
       'data.results.listings.prices.__typename',
       'data.results.listings.prices.perNight.amount',
       'data.results.listings.prices.perNight.formattedAmount',
         'data.results.listings.prices.perNight.pricePeriodDescription',
       'data.results.listings.prices.perNight.__typename',
       'data.results.listings.prices.total.amount',
       'data.results.listings.prices.total.formattedAmount',
       'data.results.listings.prices.total.roundedFormattedAmount',
       'data.results.listings.prices.total.pricePeriodDescription',
       'data.results.listings.prices.total.__typename',
        'data.results.listings.geoCode.__typename',
       'data.results.listings.amenitiesBadges[0].id',
       'data.results.listings.amenitiesBadges[0].name',
       'data.results.listings.amenitiesBadges[0].helpText',
       'data.results.listings.amenitiesBadges[0].__typename',
       'data.results.listings.rankedBadges[0].id',
       'data.results.listings.rankedBadges[0].name',
       'data.results.listings.rankedBadges[0].helpText',
       'data.results.listings.rankedBadges[0].__typename',
       'data.results.listings.superlativesBadges[0].id',
       'data.results.listings.superlativesBadges[0].name',
       'data.results.listings.superlativesBadges[0].helpText',
       'data.results.listings.superlativesBadges[0].__typename',
       'data.results.listings.virtualTourBadge.id',
       'data.results.listings.virtualTourBadge.name',
       'data.results.listings.virtualTourBadge.helpText',
       'data.results.listings.virtualTourBadge.__typename',
       'data.results.listings.priceSummary',
       'data.results.listings.priceSummarySecondary',
       'data.results.listings.priceLabel', 'data.results.listings.prices',
        'data.results.id',
       'data.results.propertyRedirectUrl', 'data.results.__typename',
       'data.results.resultCount', 'data.results.page',
       'data.results.pageSize', 'data.results.pageCount',
       'data.results.queryUUID', 'data.results.pinnedListing',
       'data.results.fromRecord', 'data.results.toRecord',
       'data.results.internalTools', 'data.results.typeaheadSuggestion.name',
       'data.results.typeaheadSuggestion.uuid',
       'data.results.typeaheadSuggestion.term',
       'data.results.typeaheadSuggestion.__typename',
       'data.results.geography.name', 'data.results.geography.lbsId',
       'data.results.geography.gaiaId', 'data.results.geography.isGeocoded',
       'data.results.geography.shouldShowMapCentralPin',
       'data.results.geography.__typename',
       'data.results.geography.description',
       'data.results.geography.primaryGeoType',
       'data.results.geography.location.latitude',
       'data.results.geography.location.longitude',
       'data.results.geography.location.__typename',
       'data.results.geography.breadcrumbs[0].name',
       'data.results.geography.breadcrumbs[0].countryCode',
       'data.results.geography.breadcrumbs[0].primaryGeoType',
       'data.results.geography.breadcrumbs[0].__typename',
       'data.results.geography.breadcrumbs[0].location.latitude',
       'data.results.geography.breadcrumbs[0].location.longitude',
       'data.results.geography.breadcrumbs[0].location.__typename',
       'data.results.destination.__typename',
       'data.results.destination.breadcrumbs[0].name',
       'data.results.destination.breadcrumbs[0].url',
       'data.results.destination.breadcrumbs[0].__typename',
       'data.results.destinationMessage.iconText',
       'data.results.destinationMessage.__typename',
       'data.results.destinationMessage.iconTitleText.title',
       'data.results.destinationMessage.iconTitleText.message',
       'data.results.destinationMessage.iconTitleText.icon',
       'data.results.destinationMessage.iconTitleText.messageValueType',
       'data.results.destinationMessage.iconTitleText.link',
       'data.results.destinationMessage.iconTitleText.__typename',
       'data.results.percentBooked.currentPercentBooked',
       'data.results.percentBooked.__typename', 'data.results.parsedParams.q',
       'data.results.parsedParams.sort',
       'data.results.parsedParams.__typename',
       'data.results.parsedParams.coreFilters.adults',
       'data.results.parsedParams.coreFilters.children',
       'data.results.parsedParams.coreFilters.pets',
       'data.results.parsedParams.coreFilters.minBedrooms',
       'data.results.parsedParams.coreFilters.maxBedrooms',
       'data.results.parsedParams.coreFilters.minBathrooms',
       'data.results.parsedParams.coreFilters.maxBathrooms',
       'data.results.parsedParams.coreFilters.minNightlyPrice',
       'data.results.parsedParams.coreFilters.maxNightlyPrice',
       'data.results.parsedParams.coreFilters.minSleeps',
       'data.results.parsedParams.coreFilters.__typename',
       'data.results.parsedParams.dates.arrivalDate',
       'data.results.parsedParams.dates.departureDate',
       'data.results.parsedParams.dates.__typename',
       'data.results.mapViewport.neLat', 'data.results.mapViewport.neLong',
       'data.results.mapViewport.swLat', 'data.results.mapViewport.swLong',
       'data.results.mapViewport.__typename',
       'data.results.globalMessages.alert',
       'data.results.globalMessages.__typename',
       'data.results.globalMessages.banner',
       'data.results.filterGroups[0].__typename',
       'data.results.filterGroups[0].groupInfo.id',
       'data.results.filterGroups[0].groupInfo.name',
       'data.results.filterGroups[0].groupInfo.__typename',
       'data.results.filterGroups[0].filters[0].count',
        'data.results.filterGroups[0].filters[0].checked',
       'data.results.filterGroups[0].filters[0].__typename',
       'data.results.filterGroups[0].filters[0].filter.id',
       'data.results.filterGroups[0].filters[0].filter.name',
       'data.results.filterGroups[0].filters[0].filter.refineByQueryArgument',
       'data.results.filterGroups[0].filters[0].filter.description',
       'data.results.filterGroups[0].filters[0].filter.__typename',
       'data.results.filterGroups[0].filters[0].filter.groupId',
       'errors[0].message', 'errors[0].extensions.errorCode',
       'errors[0].extensions.unit', 'errors[0].extensions.code',
       'errors[0].locations[0].line', 'errors[0].locations[0].column', 'data.results.listings.images[0].__typename',
       'data.results.listings.images[0].mab.banditId',
       'data.results.listings.images[0].mab.payloadId',
       'data.results.listings.images[0].mab.campaignId',
       'data.results.listings.images[0].mab.cached',
       'data.results.listings.images[0].mab.arm',
       'data.results.listings.images[0].mab.__typename', 'data.results.listings.images[0].c9_uri',
       'data.results.listings.images[0].mab', 'data.results.listings.images[0].altText', 'data.results.listings.webRatingBadges[0].id',
       'data.results.listings.webRatingBadges[0].name',
       'data.results.listings.webRatingBadges[0].helpText',
       'data.results.listings.webRatingBadges[0].__typename'})

# %%
gulfport
# Out:
#      bedrooms       type  sleeps  pets_allowed    rating  review_count  \
# 0           3      House       8         False  4.555555            18
# 1           2      Condo       4         False  4.827586            58
# 2           3      House       6          True  4.600000             5
# 3           2      House       5         False  5.000000            16
# 4           3   Townhome       8          True  4.738095            42
# ..        ...        ...     ...           ...       ...           ...
# 329         2      Condo       4         False  0.000000             0
# 330         3   Townhome       8         False  0.000000             0
# 331         2      Condo       4         False  0.000000             0
# 332         4      House       9         False  0.000000             0
# 333         2  Apartment       6         False  0.000000             0
#
#      full_bathrooms  half_bathrooms cost_night   latitude  longitude  \
# 0                 2               0       $209  30.366564 -89.113611
# 1                 2               0       $199  30.394037 -88.958335
# 2                 2               0       $250  30.365193 -89.103375
# 3                 2               1       $219  30.396346 -88.877402
# 4                 3               0       $217  30.387780 -89.025909
# ..              ...             ...        ...        ...        ...
# 329               2               0       $412  30.392552 -88.959142
# 330               2               1       $340  30.395602 -89.002762
# 331               2               0       $261  30.392651 -88.958965
# 332               2               1       $385  30.338144 -89.174757
# 333               0               0        $54  30.389645 -89.066470
#
#                                              image_url
# 0    https://media.vrbo.com/lodging/65000000/644100...
# 1    https://media.vrbo.com/lodging/25000000/248900...
# 2    https://media.vrbo.com/lodging/88000000/877600...
# 3    https://media.vrbo.com/lodging/79000000/784300...
# 4    https://media.vrbo.com/lodging/64000000/635000...
# ..                                                 ...
# 329  https://media.vrbo.com/lodging/73000000/726600...
# 330  https://media.vrbo.com/lodging/92000000/918700...
# 331  https://media.vrbo.com/lodging/92000000/918200...
# 332  https://media.vrbo.com/lodging/72000000/716300...
# 333  https://media.vrbo.com/lodging/93000000/925600...
#
# [334 rows x 12 columns]

# %%
gulfport['cost_night'] = gulfport['cost_night'].str.replace('$', '')
# Out:
# C:\Users\bswil\AppData\Local\Temp\ipykernel_18536\3821083001.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   gulfport['cost_night'] = gulfport['cost_night'].str.replace('$', '')

# %%
gulfport['cost_night'] = gulfport['cost_night'].str.replace(',', '')

# %%
gulfport = gulfport.drop(268)
gulfport = gulfport.drop(274)

# %%
gulfport['cost_night'] = gulfport['cost_night'].astype(int)

# %%
gulfport['half_bathrooms'] = gulfport['half_bathrooms']/2

# %%
gulfport['bathrooms'] = gulfport['full_bathrooms']+gulfport['half_bathrooms']

# %%
gulfport = gulfport.drop(columns={'full_bathrooms', 'half_bathrooms'})

# %%
gulfport['checkin_month'] = '10'
gulfport['checkin_day'] = '7'

# %%
gulfport['location'] = 'Gulfport Beach'
gulfport
# Out:
#      bedrooms       type  sleeps  pets_allowed    rating  review_count  \
# 0           3      House       8         False  4.555555            18
# 1           2      Condo       4         False  4.827586            58
# 2           3      House       6          True  4.600000             5
# 3           2      House       5         False  5.000000            16
# 4           3   Townhome       8          True  4.738095            42
# ..        ...        ...     ...           ...       ...           ...
# 329         2      Condo       4         False  0.000000             0
# 330         3   Townhome       8         False  0.000000             0
# 331         2      Condo       4         False  0.000000             0
# 332         4      House       9         False  0.000000             0
# 333         2  Apartment       6         False  0.000000             0
#
#      cost_night   latitude  longitude  \
# 0           209  30.366564 -89.113611
# 1           199  30.394037 -88.958335
# 2           250  30.365193 -89.103375
# 3           219  30.396346 -88.877402
# 4           217  30.387780 -89.025909
# ..          ...        ...        ...
# 329         412  30.392552 -88.959142
# 330         340  30.395602 -89.002762
# 331         261  30.392651 -88.958965
# 332         385  30.338144 -89.174757
# 333          54  30.389645 -89.066470
#
#                                              image_url  bathrooms  \
# 0    https://media.vrbo.com/lodging/65000000/644100...        2.0
# 1    https://media.vrbo.com/lodging/25000000/248900...        2.0
# 2    https://media.vrbo.com/lodging/88000000/877600...        2.0
# 3    https://media.vrbo.com/lodging/79000000/784300...        2.5
# 4    https://media.vrbo.com/lodging/64000000/635000...        3.0
# ..                                                 ...        ...
# 329  https://media.vrbo.com/lodging/73000000/726600...        2.0
# 330  https://media.vrbo.com/lodging/92000000/918700...        2.5
# 331  https://media.vrbo.com/lodging/92000000/918200...        2.0
# 332  https://media.vrbo.com/lodging/72000000/716300...        2.5
# 333  https://media.vrbo.com/lodging/93000000/925600...        0.0
#
#     checkin_month checkin_day        location
# 0              10           7  Gulfport Beach
# 1              10           7  Gulfport Beach
# 2              10           7  Gulfport Beach
# 3              10           7  Gulfport Beach
# 4              10           7  Gulfport Beach
# ..            ...         ...             ...
# 329            10           7  Gulfport Beach
# 330            10           7  Gulfport Beach
# 331            10           7  Gulfport Beach
# 332            10           7  Gulfport Beach
# 333            10           7  Gulfport Beach
#
# [332 rows x 14 columns]

# %% [markdown]
# ## Miramar

# %%
miramar = miramar.drop_duplicates('data.results.listings.listingId')

# %%
miramar = miramar.rename(columns={'data.results.listings.bedrooms':'bedrooms', 'data.results.listings.propertyType':'type',
       'data.results.listings.sleeps':'sleeps', 'data.results.listings.petsAllowed':'pets_allowed',
       'data.results.listings.averageRating':'rating',
       'data.results.listings.reviewCount':'review_count',
       'data.results.listings.bathrooms.full':'full_bathrooms',
       'data.results.listings.bathrooms.half':'half_bathrooms',
        'data.results.listings.prices.perNight.roundedFormattedAmount':'cost_night',
       'data.results.listings.geoCode.latitude':'latitude',
       'data.results.listings.geoCode.longitude':'longitude', 'data.results.listings.images[0].c6_uri':'image_url'})

# %%
miramar = miramar.drop(columns = {'data.results.listings.virtualTourBadge',
       'data.results.listings.listingId',
       'data.results.listings.detailPageUrl',
       'data.results.listings.instantBookable',
       'data.results.listings.listingNumber',
       'data.results.listings.propertyId',
        'data.results.listings.__typename',
        'data.results.listings.minStayRange.minStayHigh',
       'data.results.listings.minStayRange.minStayLow',
       'data.results.listings.minStayRange.__typename',
       'data.results.listings.propertyMetadata.headline',
       'data.results.listings.propertyMetadata.__typename',
       'data.results.listings.unitMetadata.unitName',
       'data.results.listings.unitMetadata.__typename',
        'data.results.listings.bathrooms.toiletOnly',
       'data.results.listings.bathrooms.__typename',
       'data.results.listings.spaces.__typename',
       'data.results.listings.spaces.spacesSummary.bedCountDisplay',
       'data.results.listings.spaces.spacesSummary.__typename',
       'data.results.listings.spaces.spacesSummary.area.areaValue',
       'data.results.listings.spaces.spacesSummary.area.__typename',
       'data.results.listings.geoDistance.text',
       'data.results.listings.geoDistance.relationType',
       'data.results.listings.geoDistance.__typename',
       'data.results.listings.priceSummary.priceAccurate',
       'data.results.listings.priceSummary.priceTypeId',
       'data.results.listings.priceSummary.edapEventJson',
       'data.results.listings.priceSummary.formattedAmount',
       'data.results.listings.priceSummary.roundedFormattedAmount',
       'data.results.listings.priceSummary.pricePeriodDescription',
       'data.results.listings.priceSummary.__typename',
       'data.results.listings.priceSummarySecondary.priceTypeId',
       'data.results.listings.priceSummarySecondary.edapEventJson',
       'data.results.listings.priceSummarySecondary.formattedAmount',
       'data.results.listings.priceSummarySecondary.roundedFormattedAmount',
       'data.results.listings.priceSummarySecondary.pricePeriodDescription',
       'data.results.listings.priceSummarySecondary.__typename',
       'data.results.listings.priceLabel.priceTypeId',
       'data.results.listings.priceLabel.pricePeriodDescription',
       'data.results.listings.priceLabel.__typename',
       'data.results.listings.prices.label',
       'data.results.listings.prices.mainPrice',
       'data.results.listings.prices.__typename',
       'data.results.listings.prices.perNight.amount',
       'data.results.listings.prices.perNight.formattedAmount',
         'data.results.listings.prices.perNight.pricePeriodDescription',
       'data.results.listings.prices.perNight.__typename',
       'data.results.listings.prices.total.amount',
       'data.results.listings.prices.total.formattedAmount',
       'data.results.listings.prices.total.roundedFormattedAmount',
       'data.results.listings.prices.total.pricePeriodDescription',
       'data.results.listings.prices.total.__typename',
        'data.results.listings.geoCode.__typename',
       'data.results.listings.amenitiesBadges[0].id',
       'data.results.listings.amenitiesBadges[0].name',
       'data.results.listings.amenitiesBadges[0].helpText',
       'data.results.listings.amenitiesBadges[0].__typename',
       'data.results.listings.rankedBadges[0].id',
       'data.results.listings.rankedBadges[0].name',
       'data.results.listings.rankedBadges[0].helpText',
       'data.results.listings.rankedBadges[0].__typename',
       'data.results.listings.superlativesBadges[0].id',
       'data.results.listings.superlativesBadges[0].name',
       'data.results.listings.superlativesBadges[0].helpText',
       'data.results.listings.superlativesBadges[0].__typename',
       'data.results.listings.virtualTourBadge.id',
       'data.results.listings.virtualTourBadge.name',
       'data.results.listings.virtualTourBadge.helpText',
       'data.results.listings.virtualTourBadge.__typename',
       'data.results.listings.priceLabel',
        'data.results.id',
       'data.results.propertyRedirectUrl', 'data.results.__typename',
       'data.results.resultCount', 'data.results.page',
       'data.results.pageSize', 'data.results.pageCount',
       'data.results.queryUUID', 'data.results.pinnedListing',
       'data.results.fromRecord', 'data.results.toRecord',
       'data.results.internalTools', 'data.results.typeaheadSuggestion.name',
       'data.results.typeaheadSuggestion.uuid',
       'data.results.typeaheadSuggestion.term',
       'data.results.typeaheadSuggestion.__typename',
       'data.results.geography.name', 'data.results.geography.lbsId',
       'data.results.geography.gaiaId', 'data.results.geography.isGeocoded',
       'data.results.geography.shouldShowMapCentralPin',
       'data.results.geography.__typename',
       'data.results.geography.description',
       'data.results.geography.primaryGeoType',
       'data.results.geography.location.latitude',
       'data.results.geography.location.longitude',
       'data.results.geography.location.__typename',
       'data.results.geography.breadcrumbs[0].name',
       'data.results.geography.breadcrumbs[0].countryCode',
       'data.results.geography.breadcrumbs[0].primaryGeoType',
       'data.results.geography.breadcrumbs[0].__typename',
       'data.results.geography.breadcrumbs[0].location.latitude',
       'data.results.geography.breadcrumbs[0].location.longitude',
       'data.results.geography.breadcrumbs[0].location.__typename',
       'data.results.destination.__typename',
       'data.results.destination.breadcrumbs[0].name',
       'data.results.destination.breadcrumbs[0].url',
       'data.results.destination.breadcrumbs[0].__typename',
       'data.results.destinationMessage.iconText',
       'data.results.destinationMessage.__typename',
       'data.results.destinationMessage.iconTitleText.title',
       'data.results.destinationMessage.iconTitleText.message',
       'data.results.destinationMessage.iconTitleText.icon',
       'data.results.destinationMessage.iconTitleText.messageValueType',
       'data.results.destinationMessage.iconTitleText.link',
       'data.results.destinationMessage.iconTitleText.__typename',
       'data.results.percentBooked.currentPercentBooked',
       'data.results.percentBooked.__typename', 'data.results.parsedParams.q',
       'data.results.parsedParams.sort',
       'data.results.parsedParams.__typename',
       'data.results.parsedParams.coreFilters.adults',
       'data.results.parsedParams.coreFilters.children',
       'data.results.parsedParams.coreFilters.pets',
       'data.results.parsedParams.coreFilters.minBedrooms',
       'data.results.parsedParams.coreFilters.maxBedrooms',
       'data.results.parsedParams.coreFilters.minBathrooms',
       'data.results.parsedParams.coreFilters.maxBathrooms',
       'data.results.parsedParams.coreFilters.minNightlyPrice',
       'data.results.parsedParams.coreFilters.maxNightlyPrice',
       'data.results.parsedParams.coreFilters.minSleeps',
       'data.results.parsedParams.coreFilters.__typename',
       'data.results.parsedParams.dates.arrivalDate',
       'data.results.parsedParams.dates.departureDate',
       'data.results.parsedParams.dates.__typename',
       'data.results.mapViewport.neLat', 'data.results.mapViewport.neLong',
       'data.results.mapViewport.swLat', 'data.results.mapViewport.swLong',
       'data.results.mapViewport.__typename',
       'data.results.globalMessages.alert',
       'data.results.globalMessages.__typename',
       'data.results.globalMessages.banner',
       'data.results.filterGroups[0].__typename',
       'data.results.filterGroups[0].groupInfo.id',
       'data.results.filterGroups[0].groupInfo.name',
       'data.results.filterGroups[0].groupInfo.__typename',
       'data.results.filterGroups[0].filters[0].count',
        'data.results.filterGroups[0].filters[0].checked',
       'data.results.filterGroups[0].filters[0].__typename',
       'data.results.filterGroups[0].filters[0].filter.id',
       'data.results.filterGroups[0].filters[0].filter.name',
       'data.results.filterGroups[0].filters[0].filter.refineByQueryArgument',
       'data.results.filterGroups[0].filters[0].filter.description',
       'data.results.filterGroups[0].filters[0].filter.__typename',
       'data.results.filterGroups[0].filters[0].filter.groupId', 'data.results.listings.images[0].__typename',
       'data.results.listings.images[0].mab.banditId',
       'data.results.listings.images[0].mab.payloadId',
       'data.results.listings.images[0].mab.campaignId',
       'data.results.listings.images[0].mab.cached',
       'data.results.listings.images[0].mab.arm',
       'data.results.listings.images[0].mab.__typename', 'data.results.listings.images[0].c9_uri',
       'data.results.listings.images[0].mab', 'data.results.listings.images[0].altText', 'data.results.listings.prices.total'})

# %%
miramar['cost_night'] = miramar['cost_night'].str.replace('$', '')
# Out:
# C:\Users\bswil\AppData\Local\Temp\ipykernel_18536\3361060970.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   miramar['cost_night'] = miramar['cost_night'].str.replace('$', '')

# %%
miramar['cost_night'] = miramar['cost_night'].str.replace(',', '')

# %%
miramar['cost_night'] = miramar['cost_night'].astype(int)

# %%
miramar['half_bathrooms'] = miramar['half_bathrooms']/2

# %%
miramar['bathrooms'] = miramar['full_bathrooms']+miramar['half_bathrooms']

# %%
miramar = miramar.drop(columns={'full_bathrooms', 'half_bathrooms'})

# %%
miramar['checkin_month'] = '10'
miramar['checkin_day'] = '7'

# %%
miramar['location'] = 'Miramar Beach'
miramar
# Out:
#      bedrooms      type  sleeps  pets_allowed    rating  review_count  \
# 0           2     Condo       8         False  0.000000             0
# 1           2  Townhome       6         False  4.884615            78
# 2           2     Condo       6         False  0.000000             0
# 3           2     Condo       7         False  5.000000             2
# 4           2     Condo       6          True  4.752381           105
# ..        ...       ...     ...           ...       ...           ...
# 444         2  Townhome       6         False  0.000000             0
# 445         4     House      16          True  0.000000             0
# 446         3     Condo      10         False  0.000000             0
# 447         5     House      12         False  0.000000             0
# 448         3     Condo       8          True  0.000000             0
#
#      cost_night   latitude  longitude  \
# 0           208  30.376023 -86.366389
# 1           199  30.379700 -86.384374
# 2           220  30.385716 -86.333450
# 3           270  30.375848 -86.367849
# 4           349  30.380520 -86.392109
# ..          ...        ...        ...
# 444         225  30.379950 -86.387150
# 445         901  30.382546 -86.381823
# 446         328  30.377534 -86.366441
# 447         877  30.374599 -86.349809
# 448         225  30.378497 -86.382876
#
#                                              image_url  bathrooms  \
# 0    https://media.vrbo.com/lodging/91000000/902500...        2.0
# 1    https://media.vrbo.com/lodging/25000000/240900...        2.0
# 2    https://media.vrbo.com/lodging/91000000/907900...        2.0
# 3    https://media.vrbo.com/lodging/91000000/908200...        2.0
# 4    https://media.vrbo.com/lodging/83000000/826600...        2.0
# ..                                                 ...        ...
# 444  https://media.vrbo.com/lodging/92000000/916500...        2.0
# 445  https://media.vrbo.com/lodging/93000000/928200...        4.5
# 446  https://media.vrbo.com/lodging/92000000/912100...        3.0
# 447  https://media.vrbo.com/lodging/92000000/912500...        3.0
# 448  https://media.vrbo.com/lodging/92000000/919600...        2.0
#
#     checkin_month checkin_day       location
# 0              10           7  Miramar Beach
# 1              10           7  Miramar Beach
# 2              10           7  Miramar Beach
# 3              10           7  Miramar Beach
# 4              10           7  Miramar Beach
# ..            ...         ...            ...
# 444            10           7  Miramar Beach
# 445            10           7  Miramar Beach
# 446            10           7  Miramar Beach
# 447            10           7  Miramar Beach
# 448            10           7  Miramar Beach
#
# [447 rows x 14 columns]
