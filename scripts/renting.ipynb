# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import json
import seaborn as sns
import re
from IPython.core.display import HTML

# %%
URL = 'https://www.vrbo.com/Hotel-Search?adults=2&d1=2023-05-06&d2=2023-05-13&destination=Dauphin%20Island%2C%20Alabama%2C%20United%20States%20of%20America&endDate=2023-05-13&isPets=false&latLong=30.254257%2C-88.112415&regionId=182896&selected=&semdtl=&sort=RECOMMENDED&startDate=2023-05-06&theme=&useRewards=false&userIntent='
response = requests.get(URL)

# %%
soup = BS(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html data-language="en_US" dir="ltr" lang="en">
# ...
