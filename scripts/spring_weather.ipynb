# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import json
import seaborn as sns
import re
from IPython.core.display import HTML

# %%
spring_2013 = pd.read_csv('../data/spring_2013_weather.csv')
spring_2014 = pd.read_csv('../data/spring_2014_weather.csv')
spring_2015 = pd.read_csv('../data/spring_2015_weather.csv')
spring_2016 = pd.read_csv('../data/spring_2016_weather.csv')
spring_2017 = pd.read_csv('../data/spring_2017_weather.csv')
spring_2018 = pd.read_csv('../data/spring_2018_weather.csv')
spring_2019 = pd.read_csv('../data/spring_2019_weather.csv')
spring_2020 = pd.read_csv('../data/spring_2020_weather.csv')
spring_2021 = pd.read_csv('../data/spring_2021_weather.csv')
spring_2022 = pd.read_csv('../data/spring_2022_weather.csv')
spring_2023 = pd.read_csv('../data/spring_2023_weather.csv')

# %% [markdown]
# # 2013

# %%
spring_2013 = spring_2013.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2013['location'] = spring_2013['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2014

# %%
spring_2014 = spring_2014.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2014['location'] = spring_2014['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2015

# %%
spring_2015 = spring_2015.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2015['location'] = spring_2015['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2016

# %%
spring_2016 = spring_2016.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2016['location'] = spring_2016['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2017

# %%
spring_2017 = spring_2017.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2017['location'] = spring_2017['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2018

# %%
spring_2018 = spring_2018.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2018['location'] = spring_2018['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2019

# %%
spring_2019 = spring_2019.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2019['location'] = spring_2019['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2020

# %%
spring_2020 = spring_2020.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2020['location'] = spring_2020['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2021

# %%
spring_2021 = spring_2021.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2021['location'] = spring_2021['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2022

# %%
spring_2022 = spring_2022.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2022['location'] = spring_2022['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # 2023

# %%
spring_2023 = spring_2023.drop(columns={'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'snow', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase', 'icon', 'stations', 'windgust',
        'description', 'sunrise', 'sunset', 'cloudcover', 'precip', 'precipcover'})

# %%
spring_2023['location'] = spring_2023['name'].apply(lambda x: 'Gulfport Beach' if x == 39501 else ('Isle of Palms' if x == 29451 else 'Panama City Beach' if x == 32407 else 'Dauphin Island' if x == 36528 else 'Orange Beach' if x == 36561 else 'Miramar Beach' if x == 32550 else 'Tybee Island'))

# %% [markdown]
# # All Spring Weather (minus 2023)

# %%
spring_weather = pd.merge(spring_2013, spring_2014,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')
spring_weather = pd.merge(spring_weather, spring_2015,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')
spring_weather = pd.merge(spring_weather, spring_2016,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')
spring_weather = pd.merge(spring_weather, spring_2017,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')
spring_weather = pd.merge(spring_weather, spring_2018,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')
spring_weather = pd.merge(spring_weather, spring_2019,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')
spring_weather = pd.merge(spring_weather, spring_2020,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')
spring_weather = pd.merge(spring_weather, spring_2021,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')
spring_weather = pd.merge(spring_weather, spring_2022,
        on=('name', 'datetime', 'tempmax', 'tempmin', 'temp', 'humidity', 'precipprob', 'preciptype', 'windspeed', 'conditions', 'location'),
        how='outer')

# %%
spring_weather['month_day'] = spring_weather['datetime'].str.slice(-5)

# %%
spring_weather['datetime'] = pd.to_datetime(spring_weather['datetime'])

# %%
spring_weather['month'] = spring_weather['datetime'].dt.month_name()
spring_weather['month_num'] = spring_weather['datetime'].dt.month
spring_weather['day'] = spring_weather['datetime'].dt.day

# %%
spring_weather_avgs = spring_weather.groupby(['location', 'month_num', 'day'])['temp', 'tempmax', 'tempmin', 'humidity', 'windspeed', 'precipprob'].mean().reset_index()
# Out:
# C:\Users\bswil\AppData\Local\Temp\ipykernel_24848\2861102245.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   spring_weather_avgs = spring_weather.groupby(['location', 'month_num', 'day'])['temp', 'tempmax', 'tempmin', 'humidity', 'windspeed', 'precipprob'].mean().reset_index()

# %%
spring_weather_avgs['precipprob'] = spring_weather_avgs['precipprob']/10
spring_weather_avgs = spring_weather_avgs.rename(columns = {'precipprob':'days_with_rain_10_years'})

# %%
clear_weather = spring_weather.loc[spring_weather['conditions']=='Clear'].groupby(['location', 'month_num', 'day'])['name'].count().to_frame().reset_index().rename(columns={'name':'days_clear_10_years'})

# %%
spring_weather_avgs = pd.merge(spring_weather_avgs, clear_weather,
        on=('location', 'month_num', 'day'),
        how='left')

# %%
spring_weather_avgs['days_with_rain_10_years'] = spring_weather_avgs['days_with_rain_10_years']*10
spring_weather_avgs['days_clear_10_years'] = spring_weather_avgs['days_clear_10_years']*10

# %%
spring_weather_avgs
# Out:
#              location  month_num  day   temp  tempmax  tempmin  humidity  \
# 0      Dauphin Island          3   11  64.28    71.55    57.59     89.40
# 1      Dauphin Island          3   12  58.88    67.56    51.99     76.69
# 2      Dauphin Island          3   13  57.71    66.63    49.02     76.03
# 3      Dauphin Island          3   14  59.06    68.54    50.06     77.24
# 4      Dauphin Island          3   15  60.34    69.55    51.57     79.05
# 5      Dauphin Island          3   16  61.84    70.35    53.39     80.14
# 6      Dauphin Island          3   17  62.90    71.98    54.12     80.62
# 7      Dauphin Island          3   18  63.57    71.12    55.41     80.45
# 8      Gulfport Beach          3   11  65.35    71.74    58.79     85.38
# 9      Gulfport Beach          3   12  60.30    67.84    53.34     73.79
# 10     Gulfport Beach          3   13  59.72    68.18    51.62     72.77
# 11     Gulfport Beach          3   14  61.26    69.95    53.20     72.99
# ...

# %%
spring_2023['datetime'] = pd.to_datetime(spring_2023['datetime'])

# %%
spring_2023['month'] = spring_2023['datetime'].dt.month_name()
spring_2023['month_num'] = spring_2023['datetime'].dt.month
spring_2023['day'] = spring_2023['datetime'].dt.day

# %%
spring_2023
# Out:
#      name   datetime  tempmax  tempmin  temp  humidity  precipprob preciptype  \
# 0   39501 2023-03-11     74.0     57.0  68.3      80.4           0        NaN
# 1   39501 2023-03-12     76.9     65.0  71.7      86.0         100       rain
# 2   39501 2023-03-13     66.7     50.0  58.3      63.7         100       rain
# 3   39501 2023-03-14     62.8     43.0  52.7      49.4           0        NaN
# 4   39501 2023-03-15     61.9     42.1  51.9      55.4           0        NaN
# 5   39501 2023-03-16     71.9     43.3  59.9      73.5           0        NaN
# 6   39501 2023-03-17     71.9     49.9  63.8      85.3         100       rain
# 7   39501 2023-03-18     55.9     47.0  50.9      51.8         100       rain
# 8   36528 2023-03-11     70.6     54.1  64.1      76.0           0        NaN
# 9   36528 2023-03-12     74.5     63.6  68.4      91.8         100       rain
# 10  36528 2023-03-13     63.6     49.8  56.6      64.6         100       rain
# ...
